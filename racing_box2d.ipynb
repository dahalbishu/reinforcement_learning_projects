# %%
# !pip install swig
# !pip install gymnasium[box2d]

# %%
import os
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
environment_name = 'CarRacing-v3'
env = gym.make(environment_name, render_mode= 'human')

# %%
epds = 5
for ep in range(1,epds+1):
    obs = env.reset()
    done = False
    score = 0
    truncated = False
    while not (done or truncated):
        env.render()
        action = env.action_space.sample()
        obs,reward,done,truncated,info = env.step(action)
        score += reward
    print(f"ep {ep} Score = {score}")
# Out:
# ep 1 Score = -30.147058823529832
# ep 2 Score = -33.993399339934506
# ep 3 Score = -32.20338983050896
# ep 4 Score = -29.824561403509165
# ep 5 Score = -43.28358208955294

# %%
env.close()

# %%
env??
# Out:
# Type:           TimeLimit
# String form:    <TimeLimit<OrderEnforcing<PassiveEnvChecker<CarRacing<CarRacing-v3>>>>>
# File:           c:\users\dahal\anaconda3\envs\llmhand\lib\site-packages\gymnasium\wrappers\common.py
# Source:
# class TimeLimit(
#     gym.Wrapper[ObsType, ActType, ObsType, ActType], gym.utils.RecordConstructorArgs
# ):
#     """Limits the number of steps for an environment through truncating the environment if a maximum number of timesteps is exceeded.
#
#     If a truncation is not defined inside the environment itself, this is the only place that the truncation signal is issued.
#     Critically, this is different from the `terminated` signal that originates from the underlying environment as part of the MDP.
#     No vector wrapper exists.
#
#     Example using the TimeLimit wrapper:
#         >>> from gymnasium.wrappers import TimeLimit
#         >>> from gymnasium.envs.classic_control import CartPoleEnv
#
#         >>> spec = gym.spec("CartPole-v1")
#         >>> spec.max_episode_steps
#         500
#         >>> env = gym.make("CartPole-v1")
#         >>> env  # TimeLimit is included within the environment stack
#         <TimeLimit<OrderEnforcing<PassiveEnvChecker<CartPoleEnv<CartPole-v1>>>>>
#         >>> env.spec  # doctest: +ELLIPSIS
#         EnvSpec(id='CartPole-v1', ..., max_episode_steps=500, ...)
#         >>> env = gym.make("CartPole-v1", max_episode_steps=3)
#         >>> env.spec  # doctest: +ELLIPSIS
#         EnvSpec(id='CartPole-v1', ..., max_episode_steps=3, ...)
#         >>> env = TimeLimit(CartPoleEnv(), max_episode_steps=10)
#         >>> env
#         <TimeLimit<CartPoleEnv instance>>
#
#     Example of `TimeLimit` determining the episode step
#         >>> env = gym.make("CartPole-v1", max_episode_steps=3)
#         >>> _ = env.reset(seed=123)
#         >>> _ = env.action_space.seed(123)
#         >>> _, _, terminated, truncated, _ = env.step(env.action_space.sample())
#         >>> terminated, truncated
#         (False, False)
#         >>> _, _, terminated, truncated, _ = env.step(env.action_space.sample())
#         >>> terminated, truncated
#         (False, False)
#         >>> _, _, terminated, truncated, _ = env.step(env.action_space.sample())
#         >>> terminated, truncated
#         (False, True)
#
#     Change logs:
#      * v0.10.6 - Initially added
#      * v0.25.0 - With the step API update, the termination and truncation signal is returned separately.
#     """
#
#     def __init__(
#         self,
#         env: gym.Env,
#         max_episode_steps: int,
#     ):
#         """Initializes the :class:`TimeLimit` wrapper with an environment and the number of steps after which truncation will occur.
#
#         Args:
#             env: The environment to apply the wrapper
#             max_episode_steps: the environment step after which the episode is truncated (``elapsed >= max_episode_steps``)
#         """
#         assert (
#             isinstance(max_episode_steps, int) and max_episode_steps > 0
#         ), f"Expect the `max_episode_steps` to be positive, actually: {max_episode_steps}"
#         gym.utils.RecordConstructorArgs.__init__(
#             self, max_episode_steps=max_episode_steps
#         )
#         gym.Wrapper.__init__(self, env)
#
#         self._max_episode_steps = max_episode_steps
#         self._elapsed_steps = None
#
#     def step(
#         self, action: ActType
#     ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#         """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#
#         Args:
#             action: The environment step action
#
#         Returns:
#             The environment step ``(observation, reward, terminated, truncated, info)`` with `truncated=True`
#             if the number of steps elapsed >= max episode steps
#
#         """
#         observation, reward, terminated, truncated, info = self.env.step(action)
#         self._elapsed_steps += 1
#
#         if self._elapsed_steps >= self._max_episode_steps:
#             truncated = True
#
#         return observation, reward, terminated, truncated, info
#
#     def reset(
#         self, *, seed: int | None = None, options: dict[str, Any] | None = None
#     ) -> tuple[ObsType, dict[str, Any]]:
#         """Resets the environment with :param:`**kwargs` and sets the number of steps elapsed to zero.
#
#         Args:
#             seed: Seed for the environment
#             options: Options for the environment
#
#         Returns:
#             The reset environment
#         """
#         self._elapsed_steps = 0
#         return super().reset(seed=seed, options=options)
#
#     @property
#     def spec(self) -> EnvSpec | None:
#         """Modifies the environment spec to include the `max_episode_steps=self._max_episode_steps`."""
#         if self._cached_spec is not None:
#             return self._cached_spec
#
#         env_spec = self.env.spec
#         if env_spec is not None:
#             try:
#                 env_spec = deepcopy(env_spec)
#                 env_spec.max_episode_steps = self._max_episode_steps
#             except Exception as e:
#                 gym.logger.warn(
#                     f"An exception occurred ({e}) while copying the environment spec={env_spec}"
#                 )
#                 return None
#
#         self._cached_spec = env_spec
#         return env_spec
# Init docstring:
# Initializes the :class:`TimeLimit` wrapper with an environment and the number of steps after which truncation will occur.
#
# Args:
#     env: The environment to apply the wrapper
#     max_episode_steps: the environment step after which the episode is truncated (``elapsed >= max_episode_steps``)

# %%
env = gym.make(environment_name, render_mode= 'human')
env = DummyVecEnv([lambda:env])

# %%
log_path = os.path.join('Training','Logs')
os.makedirs(log_path, exist_ok=True)

model = PPO('CnnPolicy',env,verbose = 1,tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000)
# Out:
# Logging to Training\Logs\PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 33   |
# |    iterations      | 1    |
# |    time_elapsed    | 61   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 2           |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008367535 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.151       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.299       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00989    |
# |    std                  | 0.991       |
# |    value_loss           | 0.582       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 34           |
# |    iterations           | 3            |
# |    time_elapsed         | 175          |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0095334705 |
# |    clip_fraction        | 0.0693       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.21        |
# |    explained_variance   | 0.284        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.163        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00759     |
# |    std                  | 0.979        |
# |    value_loss           | 0.466        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 4           |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008306712 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0758      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00805    |
# |    std                  | 0.975       |
# |    value_loss           | 0.472       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 5           |
# |    time_elapsed         | 302         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011723386 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.02        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 0.967       |
# |    value_loss           | 0.362       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 6            |
# |    time_elapsed         | 365          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0120153325 |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.14        |
# |    explained_variance   | 0.423        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0975       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0156      |
# |    std                  | 0.956        |
# |    value_loss           | 0.357        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 7          |
# |    time_elapsed         | 428        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01323906 |
# |    clip_fraction        | 0.14       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.11      |
# |    explained_variance   | 0.449      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0491     |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0178    |
# |    std                  | 0.948      |
# |    value_loss           | 0.413      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 8           |
# |    time_elapsed         | 482         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013487052 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.08       |
# |    explained_variance   | 0.171       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.136       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.937       |
# |    value_loss           | 0.425       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 9          |
# |    time_elapsed         | 543        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01930559 |
# |    clip_fraction        | 0.169      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.04      |
# |    explained_variance   | -0.169     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.157      |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0214    |
# |    std                  | 0.926      |
# |    value_loss           | 0.348      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 10          |
# |    time_elapsed         | 613         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.017340561 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | 0.496       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.083       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0213     |
# |    std                  | 0.914       |
# |    value_loss           | 0.325       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 11          |
# |    time_elapsed         | 678         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.020398352 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.065       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0244     |
# |    std                  | 0.911       |
# |    value_loss           | 0.222       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 12          |
# |    time_elapsed         | 741         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016945003 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | 0.664       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0222      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0186     |
# |    std                  | 0.909       |
# |    value_loss           | 0.146       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 13          |
# |    time_elapsed         | 796         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.015255915 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0438     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 0.897       |
# |    value_loss           | 0.116       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 14          |
# |    time_elapsed         | 850         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017291442 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.9        |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00817     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.884       |
# |    value_loss           | 0.102       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 15          |
# |    time_elapsed         | 913         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012331411 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00574     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.878       |
# |    value_loss           | 0.0906      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 16          |
# |    time_elapsed         | 978         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.020940622 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.84       |
# |    explained_variance   | 0.878       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00789    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.867       |
# |    value_loss           | 0.12        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 17          |
# |    time_elapsed         | 1050        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.015258664 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.81       |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00334     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0191     |
# |    std                  | 0.856       |
# |    value_loss           | 0.0789      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 18          |
# |    time_elapsed         | 1135        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.016124707 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.77       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.022      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 0.85        |
# |    value_loss           | 0.119       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 19          |
# |    time_elapsed         | 1225        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.013015788 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.75       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0177     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.019      |
# |    std                  | 0.846       |
# |    value_loss           | 0.103       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 20          |
# |    time_elapsed         | 1313        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.019206613 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.73       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0322     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0226     |
# |    std                  | 0.838       |
# |    value_loss           | 0.113       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 21          |
# |    time_elapsed         | 1373        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.016670493 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.69       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00603    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.826       |
# |    value_loss           | 0.154       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 22          |
# |    time_elapsed         | 1425        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.018258749 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.67       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0123     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.825       |
# |    value_loss           | 0.0953      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 23          |
# |    time_elapsed         | 1478        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.028727558 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00815     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.815       |
# |    value_loss           | 0.117       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 24          |
# |    time_elapsed         | 1536        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.018716566 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.62       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0102     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 0.81        |
# |    value_loss           | 0.0905      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 25          |
# |    time_elapsed         | 1597        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.021839634 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0289     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0195     |
# |    std                  | 0.806       |
# |    value_loss           | 0.0729      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 26          |
# |    time_elapsed         | 1654        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.014060435 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0186     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 0.803       |
# |    value_loss           | 0.0785      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 27          |
# |    time_elapsed         | 1710        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.017903712 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.57       |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0185     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0173     |
# |    std                  | 0.8         |
# |    value_loss           | 0.0943      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 28          |
# |    time_elapsed         | 1768        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.021859957 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.028      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.806       |
# |    value_loss           | 0.0428      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 29          |
# |    time_elapsed         | 1829        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.019749152 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.61       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00148     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0223     |
# |    std                  | 0.815       |
# |    value_loss           | 0.0539      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 30          |
# |    time_elapsed         | 1893        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.015888833 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0106      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0183     |
# |    std                  | 0.82        |
# |    value_loss           | 0.0711      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 31          |
# |    time_elapsed         | 1946        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.022244295 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00377     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0208     |
# |    std                  | 0.818       |
# |    value_loss           | 0.0816      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 32          |
# |    time_elapsed         | 1999        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.025397545 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.62       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0395     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0229     |
# |    std                  | 0.814       |
# |    value_loss           | 0.061       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 33          |
# |    time_elapsed         | 2051        |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.025624098 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0166     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0325     |
# |    std                  | 0.8         |
# |    value_loss           | 0.0523      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 34          |
# |    time_elapsed         | 2109        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.021418754 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0103      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0246     |
# |    std                  | 0.798       |
# |    value_loss           | 0.076       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 35          |
# |    time_elapsed         | 2170        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.023529824 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0234     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0228     |
# |    std                  | 0.794       |
# |    value_loss           | 0.101       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 36          |
# |    time_elapsed         | 2228        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.032087784 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.51       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0303     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0296     |
# |    std                  | 0.78        |
# |    value_loss           | 0.25        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 37         |
# |    time_elapsed         | 2283       |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.02822213 |
# |    clip_fraction        | 0.253      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.47      |
# |    explained_variance   | 0.86       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0335     |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0313    |
# |    std                  | 0.771      |
# |    value_loss           | 0.465      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 38          |
# |    time_elapsed         | 2342        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.022833806 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.43       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0331     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.764       |
# |    value_loss           | 0.105       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 39          |
# |    time_elapsed         | 2405        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.045227505 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.39       |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0297     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0359     |
# |    std                  | 0.748       |
# |    value_loss           | 0.192       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 40          |
# |    time_elapsed         | 2469        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.028055394 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.33       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0584      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0245     |
# |    std                  | 0.736       |
# |    value_loss           | 0.385       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 41          |
# |    time_elapsed         | 2524        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.032862052 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.3        |
# |    explained_variance   | 0.862       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0186      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0335     |
# |    std                  | 0.733       |
# |    value_loss           | 0.394       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 42          |
# |    time_elapsed         | 2581        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.047771644 |
# |    clip_fraction        | 0.325       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.28       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0461     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0435     |
# |    std                  | 0.723       |
# |    value_loss           | 0.212       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 43          |
# |    time_elapsed         | 2643        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.049613733 |
# |    clip_fraction        | 0.333       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0351     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0332     |
# |    std                  | 0.714       |
# |    value_loss           | 0.147       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 44          |
# |    time_elapsed         | 2704        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.050454155 |
# |    clip_fraction        | 0.324       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0318     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0406     |
# |    std                  | 0.705       |
# |    value_loss           | 0.145       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 45          |
# |    time_elapsed         | 2768        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.054977264 |
# |    clip_fraction        | 0.333       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.019       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0419     |
# |    std                  | 0.699       |
# |    value_loss           | 0.301       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 46         |
# |    time_elapsed         | 2824       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.04085081 |
# |    clip_fraction        | 0.275      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.13      |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0159     |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.036     |
# |    std                  | 0.691      |
# |    value_loss           | 0.279      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 47          |
# |    time_elapsed         | 2879        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.051034726 |
# |    clip_fraction        | 0.309       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0434      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.033      |
# |    std                  | 0.679       |
# |    value_loss           | 0.0926      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 48          |
# |    time_elapsed         | 2938        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.040709697 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0779      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0404     |
# |    std                  | 0.673       |
# |    value_loss           | 0.325       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 49          |
# |    time_elapsed         | 2995        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.066476315 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.022      |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0423     |
# |    std                  | 0.67        |
# |    value_loss           | 0.213       |
# -----------------------------------------

# %%
ppo_path = os.path.join('Training','Saved Models','PPO CarRacing')
os.makedirs(ppo_path, exist_ok=True)
model.save(ppo_path)

# %%
evaluate_policy(model,env,n_eval_episodes=10,render=True)
# Out:
# c:\Users\dahal\anaconda3\envs\llmhand\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (80.58019584566355, 77.05431970860877)

# %%
env.close()
